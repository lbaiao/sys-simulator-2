# %% [markdown]
# # Penalty
#
# Comparison between training with a penalty for low D2D SINR and training without such a penalty.

# %%
import pickle
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
from sys_simulator.general import load_with_pickle, sns_confidence_interval_plot
from copy import deepcopy
import os

# %%
EXP_NAME = 'penalizacao'
ALGO_NAME = 'dql'
OUTPUT_PATH = f'D:\\Dev\\sys-simulator-2\\figs\\{EXP_NAME}\\{ALGO_NAME}'

# ddpg
# filepath = "D:\Dev/sys-simulator-2\\data\\ddpg\\script7\\20210506-100648\\log.pickle"
# dql
filepath = "D:\Dev/sys-simulator-2\DATA\DQL\SCRIPT52\\20210428-214518\\log.pickle"



file = open(filepath, 'rb')
data = pickle.load(file)
file.close()

# %%
data.keys()
# Out:
# dict_keys(['train_bags', 'test_bags', 'elapsed_time', 'eval_every'])

# %%
EVAL_EVERY = data['eval_every']
EVAL_EVERY
# Out:
# 1000

# %%
d_train = data['train_bags']
d_test = data['test_bags']
d_train.keys()
# Out:
# dict_keys(['losses', 'mue_spectral_effs', 'd2d_spectral_effs', 'collected_states'])

# %%
xx = d_test['mue_sinrs']
xx = np.array(xx)
xx.shape
# Out:
# (1000,)

# %%
xx = d_train['mue_sinrs']
xx = np.array(xx)
xx.shape
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-32-59959fba4dc6> in <module>
# ----> 1 xx = d_train['mue_sinrs']
#       2 xx = np.array(xx)
#       3 xx.shape
#
# KeyError: 'mue_sinrs'

# %%
mue_sinrs = deepcopy(d_train['mue_sinrs'])
mue_sinrs.append(d_test['mue_sinrs'])
mue_sinrs = np.array(mue_sinrs)
mue_sinrs.shape
# Out:
# (21, 500)

# %%
d2d_sinrs = deepcopy(d_train['d2d_sinrs'])
d2d_sinrs.append(d_test['d2d_sinrs'])
d2d_sinrs = np.array(d2d_sinrs)
d2d_sinrs.shape
# Out:
# (21, 500, 2)

# %%
sinr_threshold = 6
mue_avail = deepcopy(mue_sinrs >= sinr_threshold)
mue_avail.shape
# Out:
# (21, 500)

# %%
rewards = deepcopy(d_train['rewards'])
rewards.append(d_test['rewards'])
rewards = np.array(rewards)
rewards.shape
# Out:
# (21, 500)

# %% [markdown]
# ## Fonts config

# %%
x_font = {
    'family': 'serif',
    'color':  'black',
    'weight': 'normal',
    'size': 16,
}
y_font = {
    'family': 'serif',
    'color':  'black',
    'weight': 'normal',
    'size': 16,
}
ticks_font = {
    'fontfamily': 'serif',
    'fontsize': 13
}
legends_font = {
    'size': 13,
    'family': 'serif'
}

# %% [markdown]
# ## Ticks

# %%
x_ticks = [i*EVAL_EVERY*(mue_sinrs.shape[0]-1)/5 for i in range(6)]

# %% [markdown]
# ## MUE SINR

# %%
x = np.ones(mue_sinrs.shape)
for i in range(mue_sinrs.shape[0]):
    x[i, :] = i
x = x.reshape(-1)
x *= EVAL_EVERY

# %%
mu = mue_sinrs.mean(axis=1)
std = mue_sinrs.std(axis=1)
conf95 = 1.96 * std / np.sqrt(mue_sinrs.shape[1])

# %%
plt.figure()
plt.plot(mu)
plt.plot(std)
plt.plot(conf95)
plt.show()

# %%
plt.figure(figsize=(10,7))
sns.lineplot(x=x, y=mue_sinrs.reshape(-1))
plt.xlabel('Steps', fontdict=x_font)
plt.ylabel('Average MUE SINR [dB]', fontdict=y_font)
plt.xticks(x_ticks, **ticks_font)
plt.yticks(**ticks_font)
fig_name = 'mue-sinr'
svg_path = f'{OUTPUT_PATH}\\{fig_name}.svg'
eps_path = f'{OUTPUT_PATH}\\{fig_name}.eps'
print(svg_path)
# save fig
plt.savefig(svg_path)
os.system(f'magick convert {svg_path} {eps_path}')
plt.show()
# Out:
# D:\Dev\sys-simulator-2\figs\convergencia\ddpg\mue-sinr.svg

# %% [markdown]
# ## D2D SINR

# %%
y_font
# Out:
# {'family': 'serif', 'color': 'black', 'weight': 'normal', 'size': 16}

# %%
plt.figure(figsize=(10,7))
sns.lineplot(x=x, y=d2d_sinrs[:,:,0].reshape(-1), label='Device 1')
sns.lineplot(x=x, y=d2d_sinrs[:,:,1].reshape(-1), label='Device 2')
plt.xlabel('Steps', fontdict=x_font)
plt.ylabel('Average D2D SINR [dB]', fontdict=y_font)
plt.xticks(x_ticks, **ticks_font)
plt.yticks(**ticks_font)
plt.legend(prop=legends_font)
fig_name = 'd2d-sinr'
svg_path = f'{OUTPUT_PATH}\\{fig_name}.svg'
eps_path = f'{OUTPUT_PATH}\\{fig_name}.eps'
print(svg_path)
# save fig
plt.savefig(svg_path)
os.system(f'magick convert {svg_path} {eps_path}')
plt.show()
# Out:
# D:\Dev\sys-simulator-2\figs\convergencia\ddpg\d2d-sinr.svg

# %% [markdown]
# ## MUE availability

# %%
plt.figure(figsize=(10,7))
sns.lineplot(x=x, y=mue_avail.reshape(-1))
plt.xlabel('Steps', fontdict=x_font)
plt.ylabel('Average MUE availability', fontdict=y_font)
plt.xticks(x_ticks, **ticks_font)
plt.yticks([0., .2, .4, .6, .8, .9, .95, 1.], **ticks_font)
fig_name = 'mue-availability'
svg_path = f'{OUTPUT_PATH}\\{fig_name}.svg'
eps_path = f'{OUTPUT_PATH}\\{fig_name}.eps'
print(svg_path)
# save fig
plt.savefig(svg_path)
os.system(f'magick convert {svg_path} {eps_path}')
plt.show()
# Out:
# D:\Dev\sys-simulator-2\figs\convergencia\ddpg\mue-availability.svg

# %% [markdown]
# ## Rewards

# %%
plt.figure(figsize=(10,7))
sns.lineplot(x=x, y=rewards.reshape(-1))
plt.xlabel('Steps', fontdict=x_font)
plt.ylabel('Average Rewards', fontdict=y_font)
plt.xticks(x_ticks, **ticks_font)
plt.yticks(**ticks_font)
fig_name = 'rewards'
svg_path = f'{OUTPUT_PATH}\\{fig_name}.svg'
eps_path = f'{OUTPUT_PATH}\\{fig_name}.eps'
print(svg_path)
# save fig
plt.savefig(svg_path)
os.system(f'magick convert {svg_path} {eps_path}')
plt.show()
# Out:
# D:\Dev\sys-simulator-2\figs\convergencia\ddpg\rewards.svg
