# %% [markdown]
# # Notebook for visualizing general scratch1 results

# %%
import pickle
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

# %%
filepath = 'D:\\Dev\\sys-simulator-2\\data\\general\\scratch1.pickle'
file = open(filepath, 'rb')
data = pickle.load(file)

# %%
# for (i, c) in zip([2,5,10], data['action_counts_total']):
#     plt.figure()
#     plt.plot(np.mean(c, axis=0), '*',label='mean')
#     plt.plot(np.var(c, axis=0), 'x', label='variance')
#     plt.legend()
#     plt.title(f'Actions Frequencies, N={i}')

# plt.show()

# %%
d2d_speffs_total = data['d2d_speffs_total']
mue_success_rate = data['mue_success_rate']

d2d_speffs_avg = list()
for i, d in enumerate(d2d_speffs_total):
    d2d_speffs_avg.append(np.average(d))

fig2, ax1 = plt.subplots(figsize=(7,5))
ax1.set_xlabel('Iteration', fontsize='x-large', )
ax1.set_ylabel('D2D Summed Spectral Efficiency [bps/Hz]', color='tab:blue', fontsize='x-large')
ax1.plot(d2d_speffs_avg, '.', color='tab:blue', markersize=10)
ax1.tick_params(axis='both', labelsize=12)

ax2 = ax1.twinx()
ax2.set_ylabel('MUE Success Rate', color='tab:red', fontsize='x-large')
ax2.plot(mue_success_rate, '.', color='tab:red', markersize=10)
ax2.tick_params(axis='both', labelsize=12)
fig2.tight_layout()

plt.title(f'mue avg success rate: {np.mean(mue_success_rate)}')

# fig2, ax1 = plt.subplots()
# ax1.set_xlabel('Number of D2D pairs in the RB')
# ax1.set_ylabel('D2D Average Spectral Efficiency [bps/Hz]', color='tab:blue')
# ax1.plot(d2d_speffs_avg_total, '.', color='tab:blue')

# ax2 = ax1.twinx()
# ax2.set_ylabel('MUE Success Rate', color='tab:red')
# ax2.plot(mue_success_avg_total, '.', color='tab:red')
# fig2.tight_layout()

plt.show()

# %%
print(np.mean(mue_success_rate))
# Out:
# 0.9505

# %%
actions = data['chosen_actions']
plt.hist(actions)
# Out:
# (array([798.,   0., 821.,   0.,   0., 823.,   0., 790.,   0., 768.]),
#  array([0. , 0.4, 0.8, 1.2, 1.6, 2. , 2.4, 2.8, 3.2, 3.6, 4. ]),
#  <a list of 10 Patch objects>)

# %%
d2d_individual_speffs = data['d2d_individual_speffs']
d2d_individual_mean_speffs = data['d2d_individual_mean_speffs']

# %%
d2d_individual_speffs.shape
# Out:
# (2000, 2)

# %%
index = 20
plt.plot(d2d_individual_mean_speffs[:index], '.', label='mean')
plt.plot(d2d_individual_speffs[:index, 0], '.', label='d2d1')
plt.plot(d2d_individual_speffs[:index, 1], '.', label='d2d2')
plt.legend()

# %% [markdown]
# $P_i = \frac{p_{max}}{10^i}, i \in \{0,1,2,3,4\}$
