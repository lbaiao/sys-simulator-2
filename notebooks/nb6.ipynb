# %% [markdown]
# # Notebook for making the figures for the text

# %%
import pickle
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
from sys_simulator.general import load_with_pickle, sns_confidence_interval_plot

def db_to_power(x):
    return 10**(x/10)
# Out:
# In D:\Users\lucas\anaconda3\envs\masters\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The text.latex.preview rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In D:\Users\lucas\anaconda3\envs\masters\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The mathtext.fallback_to_cm rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In D:\Users\lucas\anaconda3\envs\masters\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle: Support for setting the 'mathtext.fallback_to_cm' rcParam is deprecated since 3.3 and will be removed two minor releases later; use 'mathtext.fallback : 'cm' instead.
# In D:\Users\lucas\anaconda3\envs\masters\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The validate_bool_maybe_none function was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# ...

# %% [markdown]
# # Fully descentralized and fully centralized DQL schemes. 500 environment interations.
# ------
# Channel to BS: NLOS winner channel model. Channel to D2D: BAN channel model.

# %%
discent_filepath = 'D:\Dev\sys-simulator-2\data\dql\script49\\20210204-120959\log.pickle'
discent_data = load_with_pickle(discent_filepath)
cent_filepath = "D:\Dev\sys-simulator-2\data\dql\script48\\20210204-131150\log.pickle"
cent_data = load_with_pickle(cent_filepath)
rnd_search_path = 'D:\Dev\sys-simulator-2\data\\benchmarks\script2\\20210205-143952\log.pickle'
rnd_search_data = load_with_pickle(rnd_search_path)

# %% [markdown]
# ### MUE availability

# %%
y_label = 'MUE Availability'
sns_confidence_interval_plot(
    np.array(discent_data['mue_success_rate']),
    y_label,
    'DLDE'
)
sns_confidence_interval_plot(
    np.array(cent_data['mue_success_rate']),
    y_label,
    'CLCE'
)

# %% [markdown]
# ### D2D Spectral efficiencies

# %%
y_label = 'Spectral efficiency [bps/Hz]'
sns_confidence_interval_plot(
    np.array(discent_data['d2d_speffs']),
    y_label,
    'DLDE'
)
sns_confidence_interval_plot(
    np.array(cent_data['d2d_speffs']),
    y_label,
    'CLCE'
)

# %% [markdown]
# ### MUE Spectral efficiencies

# %%
y_label = 'Spectral efficiency [bps/Hz]'
sns_confidence_interval_plot(
    np.array(discent_data['mue_speffs']),
    y_label,
    'DLDE'
)
sns_confidence_interval_plot(
    np.array(cent_data['mue_speffs']),
    y_label,
    'CLCE'
)

# explicar o pico em N=2

# %% [markdown]
# # Fully distributed and fully centralized DQL schemes. 1000 environment interations.
# ------
# Channel to BS: NLOS winner channel model. Channel to D2D: BAN channel model.

# %%
discent_filepath = 'D:\Dev\sys-simulator-2\data\dql\script49\\20210202-210757\log.pickle'
discent_data = load_with_pickle(discent_filepath)
cent_filepath = "D:\Dev\sys-simulator-2\data\dql\script48\\20210202-090733\log.pickle"
cent_data = load_with_pickle(cent_filepath)
rnd_search_path = 'D:\Dev\sys-simulator-2\data\\benchmarks\script2\\20210205-143952\log.pickle'
rnd_search_data = load_with_pickle(rnd_search_path)

# %% [markdown]
# ### MUE availability

# %%
y_label = 'MUE Availability'
sns_confidence_interval_plot(
    np.array(discent_data['mue_success_rate']),
    y_label,
    'DLDE'
)
sns_confidence_interval_plot(
    np.array(cent_data['mue_success_rate']),
    y_label,
    'CLCE'
)
sns_confidence_interval_plot(
    np.array(rnd_search_data['mue_success_rate']),
    y_label,
    'random search'
)

# %% [markdown]
# ### D2D Spectral efficiencies

# %%
y_label = 'Spectral efficiency [bps/Hz]'
sns_confidence_interval_plot(
    np.array(discent_data['d2d_speffs']),
    y_label,
    'DLDE'
)
sns_confidence_interval_plot(
    np.array(cent_data['d2d_speffs']),
    y_label,
    'CLCE'
)

# %% [markdown]
# ### MUE Spectral efficiencies

# %%
y_label = 'Spectral efficiency [bps/Hz]'
sns_confidence_interval_plot(
    np.array(discent_data['mue_speffs']),
    y_label,
    'DLDE'
)
sns_confidence_interval_plot(
    np.array(cent_data['mue_speffs']),
    y_label,
    'CLCE'
)

# %% [markdown]
# # Centralized learning-Distributed execution DQL
# ------
# Channel to BS: NLOS winner channel model. Channel to D2D: BAN channel model.

# %%
clde_path = "D:\Dev\sys-simulator-2\data\dql\script47\\20210128-191421\log.pickle"
clde_data = load_with_pickle(clde_path)
discent_filepath = 'D:\Dev\sys-simulator-2\data\dql\script49\\20210202-210757\log.pickle'
discent_data = load_with_pickle(discent_filepath)

# %% [markdown]
# ### MUE availability

# %%
y_label = 'MUE Availability'
sns_confidence_interval_plot(
    np.array(clde_data['mue_success_rate']),
    y_label,
    'CLDE'
)
sns_confidence_interval_plot(
    np.array(discent_data['mue_success_rate']),
    y_label,
    'DLDE'
)

# %% [markdown]
# ### D2D Spectral efficiencies

# %%
y_label = 'Spectral efficiency [bps/Hz]'
sns_confidence_interval_plot(
    np.array(clde_data['d2d_speffs']),
    y_label,
    'CLDE'
)
sns_confidence_interval_plot(
    np.array(discent_data['d2d_speffs']),
    y_label,
    'DLDE'
)

# %% [markdown]
# ### MUE Spectral efficiencies

# %%
y_label = 'Spectral efficiency [bps/Hz]'
sns_confidence_interval_plot(
    np.array(clde_data['mue_speffs']),
    y_label,
    'CLDE'
)
sns_confidence_interval_plot(
    np.array(discent_data['mue_speffs']),
    y_label,
    'DLDE'
)

# %% [markdown]
# # Fully descentralized A2C schemes. 500 environment interations.
# ------
# Channel to BS: NLOS winner channel model. Channel to D2D: BAN channel model.

# %%
discent_filepath = 'D:\Dev\sys-simulator-2\data\\a2c\script15\\20210212-170832\log.pickle'
discent_data = load_with_pickle(discent_filepath)
# cent_filepath = "D:\Dev\sys-simulator-2\data\dql\script48\\20210204-131150\log.pickle"
# cent_data = load_with_pickle(cent_filepath)

# %% [markdown]
# ### MUE availability

# %%
y_label = 'MUE Availability'
# sns_confidence_interval_plot(
#     np.array(clde_data['mue_success_rate']),
#     y_label,
#     'CLDE'
# )
sns_confidence_interval_plot(
    np.array(discent_data['mue_success_rate']),
    y_label,
    'DLDE'
)

# %% [markdown]
# ### D2D Spectral efficiencies

# %%
y_label = 'Spectral efficiency [bps/Hz]'
# sns_confidence_interval_plot(
#     np.array(clde_data['d2d_speffs']),
#     y_label,
#     'CLDE'
# )
sns_confidence_interval_plot(
    np.array(discent_data['d2d_speffs']),
    y_label,
    'DLDE'
)

# %% [markdown]
# ### MUE Spectral efficiencies

# %%
y_label = 'Spectral efficiency [bps/Hz]'
# sns_confidence_interval_plot(
#     np.array(clde_data['mue_speffs']),
#     y_label,
#     'CLDE'
# )
sns_confidence_interval_plot(
    np.array(discent_data['mue_speffs']),
    y_label,
    'DLDE'
)

# %% [markdown]
# # Centralized learning-Distributed execution A2C
# ------
# Channel to BS: NLOS winner channel model. Channel to D2D: BAN channel model.

# %%
clde_path = "D:\Dev\sys-simulator-2\data\\a2c\script13\\20210211-145613\log.pickle"
clde_data = load_with_pickle(clde_path)
discent_filepath = 'D:\Dev\sys-simulator-2\data\\a2c\script15\\20210212-170832\log.pickle'
discent_data = load_with_pickle(discent_filepath)

# %%
y_label = 'MUE Availability'
sns_confidence_interval_plot(
    np.array(clde_data['mue_success_rate']),
    y_label,
    'CLDE'
)
sns_confidence_interval_plot(
    np.array(discent_data['mue_success_rate']),
    y_label,
    'DLDE'
)

# %% [markdown]
# ### D2D Spectral efficiencies

# %%
y_label = 'Spectral efficiency [bps/Hz]'
sns_confidence_interval_plot(
    np.array(clde_data['d2d_speffs']),
    y_label,
    'CLDE'
)
sns_confidence_interval_plot(
    np.array(discent_data['d2d_speffs']),
    y_label,
    'DLDE'
)

# %% [markdown]
# ### MUE Spectral efficiencies

# %%
y_label = 'Spectral efficiency [bps/Hz]'
sns_confidence_interval_plot(
    np.array(clde_data['mue_speffs']),
    y_label,
    'CLDE'
)
sns_confidence_interval_plot(
    np.array(discent_data['mue_speffs']),
    y_label,
    'DLDE'
)

# %% [markdown]
# # Benchmark

# %%
random_path = "D:\Dev\sys-simulator-2\data\\benchmarks\script1\\20210204-213332\log.pickle"
random_data = load_with_pickle(random_path)
rnd_search_path = 'D:\Dev\sys-simulator-2\data\\benchmarks\script2\\20210205-143952\log.pickle'
rnd_search_data = load_with_pickle(rnd_search_path)
dql_clde_path = "D:\Dev\sys-simulator-2\data\dql\script47\\20210128-191421\log.pickle"
dql_clde_data = load_with_pickle(dql_clde_path)
dql_discent_filepath = 'D:\Dev\sys-simulator-2\data\dql\script49\\20210202-210757\log.pickle'
dql_discent_data = load_with_pickle(dql_discent_filepath)
a2c_clde_path = "D:\Dev\sys-simulator-2\data\\a2c\script13\\20210211-145613\log.pickle"
a2c_clde_data = load_with_pickle(a2c_clde_path)
a2c_discent_filepath = 'D:\Dev\sys-simulator-2\data\\a2c\script15\\20210212-170832\log.pickle'
a2c_discent_data = load_with_pickle(a2c_discent_filepath)

# %% [markdown]
# ### MUE availability

# %%
y_label = 'MUE Availability'
sns_confidence_interval_plot(
    np.array(dql_clde_data['mue_success_rate']),
    y_label,
    'DQL CLDE'
)
sns_confidence_interval_plot(
    np.array(dql_discent_data['mue_success_rate']),
    y_label,
    'DQL DLDE'
)
sns_confidence_interval_plot(
    np.array(a2c_clde_data['mue_success_rate']),
    y_label,
    'A2C CLDE'
)
sns_confidence_interval_plot(
    np.array(a2c_discent_data['mue_success_rate']),
    y_label,
    'A2C DLDE'
)
sns_confidence_interval_plot(
    np.array(random_data['mue_success_rate']),
    y_label,
    'random choice'
)
sns_confidence_interval_plot(
    np.array(rnd_search_data['mue_success_rate']),
    y_label,
    'random search'
)

# %% [markdown]
# ### D2D spectral efficiencies

# %%
y_label = 'Spectral efficiency [bps/Hz]'
sns_confidence_interval_plot(
    np.array(dql_clde_data['d2d_speffs']),
    y_label,
    'DQL CLDE'
)
sns_confidence_interval_plot(
    np.array(dql_discent_data['d2d_speffs']),
    y_label,
    'DQL DLDE'
)
sns_confidence_interval_plot(
    np.array(a2c_clde_data['d2d_speffs']),
    y_label,
    'A2C CLDE'
)
sns_confidence_interval_plot(
    np.array(a2c_discent_data['d2d_speffs']),
    y_label,
    'A2C DLDE'
)
sns_confidence_interval_plot(
    np.array(random_data['d2d_speffs']),
    y_label,
    'random choice'
)
sns_confidence_interval_plot(
    np.array(rnd_search_data['d2d_speffs']),
    y_label,
    'random search'
)

# %% [markdown]
# ### MUE spectral efficiencies

# %%
y_label = 'Spectral efficiency [bps/Hz]'
sns_confidence_interval_plot(
    np.array(dql_clde_data['mue_speffs']),
    y_label,
    'DQL CLDE'
)
sns_confidence_interval_plot(
    np.array(dql_discent_data['mue_speffs']),
    y_label,
    'DQL DLDE'
)
sns_confidence_interval_plot(
    np.array(a2c_clde_data['mue_speffs']),
    y_label,
    'A2C CLDE'
)
sns_confidence_interval_plot(
    np.array(a2c_discent_data['mue_speffs']),
    y_label,
    'A2C DLDE'
)
sns_confidence_interval_plot(
    np.array(random_data['mue_speffs']),
    y_label,
    'random choice'
)
sns_confidence_interval_plot(
    np.array(rnd_search_data['mue_speffs']),
    y_label,
    'random search'
)

# %% [markdown]
# ## Proving why the random search is the worst scheme

# %% [markdown]
# ### Random search

# %%
rnd_search_path = 'D:\Dev\sys-simulator-2\data\\benchmarks\script3\\20210207-115227\log.pickle'
rnd_data = load_with_pickle(rnd_search_path)

rewards = rnd_data['rewards']
pathlosses = rnd_data['pathlosses_d2d_to_bs']

fig2, ax1 = plt.subplots(figsize=(7,5))
ax1.set_xlabel('Time step', fontsize='x-large', )
ax1.set_ylabel('Reward', color='tab:blue', fontsize='x-large')
ax1.plot(rewards, '-.', color='tab:blue', markersize=10)
ax1.tick_params(axis='both', labelsize=12)

ax2 = ax1.twinx()
ax2.set_ylabel('Pathloss [dB]', color='tab:red', fontsize='x-large')
ax2.plot(pathlosses, '-.', color='tab:red', markersize=10)
ax2.tick_params(axis='both', labelsize=12)
fig2.tight_layout()

# %%
rnd_search_path = 'D:\Dev\sys-simulator-2\data\\benchmarks\script3\\20210207-114840\log.pickle'
rnd_data = load_with_pickle(rnd_search_path)

rewards = rnd_data['rewards']
pathlosses = rnd_data['pathlosses_d2d_to_bs']

fig2, ax1 = plt.subplots(figsize=(7,5))
ax1.set_xlabel('Time step', fontsize='x-large', )
ax1.set_ylabel('Reward', color='tab:blue', fontsize='x-large')
ax1.plot(rewards, '-.', color='tab:blue', markersize=10)
ax1.tick_params(axis='both', labelsize=12)

ax2 = ax1.twinx()
ax2.set_ylabel('Pathloss [dB]', color='tab:red', fontsize='x-large')
ax2.plot(pathlosses, '-.', color='tab:red', markersize=10)
ax2.tick_params(axis='both', labelsize=12)
fig2.tight_layout()

# %% [markdown]
# ### CLCD

# %%
central_dqn_path = 'D:\Dev\sys-simulator-2\data\dql\script50\\20210207-115259\log.pickle'
central_dqn_data = load_with_pickle(central_dqn_path)

rewards = central_dqn_data['rewards'][0][0]
pathlosses = central_dqn_data['pathlosses_d2d_to_bs'][0][0]

fig2, ax1 = plt.subplots(figsize=(7,5))
ax1.set_xlabel('Time step', fontsize='x-large', )
ax1.set_ylabel('Reward', color='tab:blue', fontsize='x-large')
ax1.plot(rewards, '-.', color='tab:blue', markersize=10)
ax1.tick_params(axis='both', labelsize=12)

ax2 = ax1.twinx()
ax2.set_ylabel('Pathloss [dB]', color='tab:red', fontsize='x-large')
ax2.plot(pathlosses, '-.', color='tab:red', markersize=10)
ax2.tick_params(axis='both', labelsize=12)
fig2.tight_layout()

# %%
rewards = central_dqn_data['rewards'][0][0]
actions = central_dqn_data['actions'][0]
actions = [i[0] for i in actions]

fig2, ax1 = plt.subplots(figsize=(7,5))
ax1.set_xlabel('Time step', fontsize='x-large', )
ax1.set_ylabel('Reward', color='tab:blue', fontsize='x-large')
ax1.plot(rewards, '-.', color='tab:blue', markersize=5)
ax1.tick_params(axis='both', labelsize=12)

ax2 = ax1.twinx()
ax2.set_ylabel('Action Index', color='tab:red', fontsize='x-large')
ax2.plot(actions, '.', color='tab:red', markersize=10)
ax2.tick_params(axis='both', labelsize=12)
fig2.tight_layout()

# %%
actions = central_dqn_data['actions'][0]
actions = [i[0] for i in actions]
pathlosses = central_dqn_data['pathlosses_d2d_to_bs'][0][0]

fig2, ax1 = plt.subplots(figsize=(7,5))
ax1.set_xlabel('Time step', fontsize='x-large', )
ax1.set_ylabel('Action Index', color='tab:blue', fontsize='x-large')
ax1.plot(actions, '.', color='tab:blue', markersize=10)
ax1.tick_params(axis='both', labelsize=12)

ax2 = ax1.twinx()
ax2.set_ylabel('Pathloss [dB]', color='tab:red', fontsize='x-large')
ax2.plot(pathlosses, '-.', color='tab:red', markersize=10)
ax2.tick_params(axis='both', labelsize=12)
fig2.tight_layout()

# %% [markdown]
# ### Fixed zero power

# %%
zero_path = 'D:\Dev\sys-simulator-2\data\\benchmarks\script4\\20210206-195910\log.pickle'
zero_data = load_with_pickle(zero_path)

# %%
rewards = zero_data['rewards']
pathlosses = zero_data['pathlosses_d2d_to_bs']

fig2, ax1 = plt.subplots(figsize=(7,5))
ax1.set_xlabel('Time step', fontsize='x-large', )
ax1.set_ylabel('Reward', color='tab:blue', fontsize='x-large')
ax1.plot(rewards, '.', color='tab:blue', markersize=10)
ax1.tick_params(axis='both', labelsize=12)

ax2 = ax1.twinx()
ax2.set_ylabel('Pathloss [dB]', color='tab:red', fontsize='x-large')
ax2.plot(pathlosses, '-.', color='tab:red', markersize=10)
ax2.tick_params(axis='both', labelsize=12)
fig2.tight_layout()
