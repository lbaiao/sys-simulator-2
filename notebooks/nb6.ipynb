# %% [markdown]
# # Notebook for making the figures for the text

# %%
import pickle
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
from sys_simulator.general import load_with_pickle, sns_confidence_interval_plot

def db_to_power(x):
    return 10**(x/10)

# %% [markdown]
# # Fully descentralized and fully centralized schemes. 500 environment interations.
# ------
# NLOS winner channel model.

# %%
discent_filepath = 'D:\Dev\sys-simulator-2\data\dql\script49\\20210204-120959\log.pickle'
discent_data = load_with_pickle(discent_filepath)
cent_filepath = "D:\Dev\sys-simulator-2\data\dql\script48\\20210204-131150\log.pickle"
cent_data = load_with_pickle(cent_filepath)
rnd_search_path = 'D:\Dev\sys-simulator-2\data\\benchmarks\script2\\20210204-221806\log.pickle'
rnd_search_data = load_with_pickle(rnd_search_path)

# %% [markdown]
# ### MUE availability

# %%
y_label = 'MUE Availability'
sns_confidence_interval_plot(
    np.array(discent_data['mue_success_rate']),
    y_label,
    'DLDE'
)
sns_confidence_interval_plot(
    np.array(cent_data['mue_success_rate']),
    y_label,
    'CLCE'
)

# %% [markdown]
# ### D2D Spectral efficiencies

# %%
y_label = 'Spectral efficiency [bps/Hz]'
sns_confidence_interval_plot(
    np.array(discent_data['d2d_speffs']),
    y_label,
    'DLDE'
)
sns_confidence_interval_plot(
    np.array(cent_data['d2d_speffs']),
    y_label,
    'CLCE'
)

# %% [markdown]
# ### MUE Spectral efficiencies

# %%
y_label = 'Spectral efficiency [bps/Hz]'
sns_confidence_interval_plot(
    np.array(discent_data['mue_speffs']),
    y_label,
    'DLDE'
)
sns_confidence_interval_plot(
    np.array(cent_data['mue_speffs']),
    y_label,
    'CLCE'
)

# %% [markdown]
# # Fully distributed and fully centralized schemes. 1000 environment interations.
# ------
# NLOS winner channel model.

# %%
discent_filepath = 'D:\Dev\sys-simulator-2\data\dql\script49\\20210202-210757\log.pickle'
discent_data = load_with_pickle(discent_filepath)
cent_filepath = "D:\Dev\sys-simulator-2\data\dql\script48\\20210202-090733\log.pickle"
cent_data = load_with_pickle(cent_filepath)
rnd_search_path = 'D:\Dev\sys-simulator-2\data\\benchmarks\script2\\20210204-221806\log.pickle'
rnd_search_data = load_with_pickle(rnd_search_path)

# %% [markdown]
# ### MUE availability

# %%
y_label = 'MUE Availability'
sns_confidence_interval_plot(
    np.array(discent_data['mue_success_rate']),
    y_label,
    'DLDE'
)
sns_confidence_interval_plot(
    np.array(cent_data['mue_success_rate']),
    y_label,
    'CLCE'
)
sns_confidence_interval_plot(
    np.array(rnd_search_data['mue_success_rate']),
    y_label,
    'random search'
)

# %% [markdown]
# ### D2D Spectral efficiencies

# %%
y_label = 'Spectral efficiency [bps/Hz]'
sns_confidence_interval_plot(
    np.array(discent_data['d2d_speffs']),
    y_label,
    'DLDE'
)
sns_confidence_interval_plot(
    np.array(cent_data['d2d_speffs']),
    y_label,
    'CLCE'
)

# %% [markdown]
# ### MUE Spectral efficiencies

# %%
y_label = 'Spectral efficiency [bps/Hz]'
sns_confidence_interval_plot(
    np.array(discent_data['mue_speffs']),
    y_label,
    'DLDE'
)
sns_confidence_interval_plot(
    np.array(cent_data['mue_speffs']),
    y_label,
    'CLCE'
)

# %% [markdown]
# # Centralized learning-Distributed execution
# ------
# NLOS winner channel model.

# %%
clde_path = "D:\Dev\sys-simulator-2\data\dql\script47\\20210128-191421\log.pickle"
clde_data = load_with_pickle(clde_path)
discent_filepath = 'D:\Dev\sys-simulator-2\data\dql\script49\\20210202-210757\log.pickle'
discent_data = load_with_pickle(discent_filepath)

# %% [markdown]
# ## MUE availability

# %%
y_label = 'MUE Availability'
sns_confidence_interval_plot(
    np.array(clde_data['mue_success_rate']),
    y_label,
    'CLDE'
)
sns_confidence_interval_plot(
    np.array(discent_data['mue_success_rate']),
    y_label,
    'DLDE'
)

# %% [markdown]
# ### D2D Spectral efficiencies

# %%
y_label = 'Spectral efficiency [bps/Hz]'
sns_confidence_interval_plot(
    np.array(clde_data['d2d_speffs']),
    y_label,
    'CLDE'
)
sns_confidence_interval_plot(
    np.array(discent_data['d2d_speffs']),
    y_label,
    'DLDE'
)

# %% [markdown]
# ### MUE Spectral efficiencies

# %%
y_label = 'Spectral efficiency [bps/Hz]'
sns_confidence_interval_plot(
    np.array(clde_data['mue_speffs']),
    y_label,
    'CLDE'
)
sns_confidence_interval_plot(
    np.array(discent_data['mue_speffs']),
    y_label,
    'DLDE'
)

# %% [markdown]
# # Benchmark

# %%
random_path = "D:\Dev\sys-simulator-2\data\\benchmarks\script1\\20210204-213332\log.pickle"
random_data = load_with_pickle(random_path)
rnd_search_path = 'D:\Dev\sys-simulator-2\data\\benchmarks\script2\\20210204-221806\log.pickle'
rnd_search_data = load_with_pickle(rnd_search_path)
clde_path = "D:\Dev\sys-simulator-2\data\dql\script47\\20210128-191421\log.pickle"
clde_data = load_with_pickle(clde_path)
discent_filepath = 'D:\Dev\sys-simulator-2\data\dql\script49\\20210202-210757\log.pickle'
discent_data = load_with_pickle(discent_filepath)

# %% [markdown]
# ### MUE availability

# %%
y_label = 'MUE Availability'
sns_confidence_interval_plot(
    np.array(clde_data['mue_success_rate']),
    y_label,
    'CLDE'
)
sns_confidence_interval_plot(
    np.array(discent_data['mue_success_rate']),
    y_label,
    'DLDE'
)
sns_confidence_interval_plot(
    np.array(random_data['mue_success_rate']),
    y_label,
    'random choice'
)
sns_confidence_interval_plot(
    np.array(rnd_search_data['mue_success_rate']),
    y_label,
    'random search'
)

# %% [markdown]
# ### D2D spectral efficiencies

# %%
y_label = 'Spectral efficiency [bps/Hz]'
sns_confidence_interval_plot(
    np.array(clde_data['d2d_speffs']),
    y_label,
    'CLDE'
)
sns_confidence_interval_plot(
    np.array(discent_data['d2d_speffs']),
    y_label,
    'DLDE'
)
sns_confidence_interval_plot(
    np.array(random_data['d2d_speffs']),
    y_label,
    'random choice'
)
sns_confidence_interval_plot(
    np.array(rnd_search_data['d2d_speffs']),
    y_label,
    'random search'
)
# Out:
# <ipython-input-48-566996576b55>:18: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   np.array(rnd_search_data['d2d_speffs']),
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# D:\Users\lucas\anaconda3\envs\masters\lib\site-packages\pandas\core\arrays\categorical.py in __init__(self, values, categories, ordered, dtype, fastpath)
#     342             try:
# --> 343                 codes, categories = factorize(values, sort=True)
#     344             except TypeError as err:
#
# D:\Users\lucas\anaconda3\envs\masters\lib\site-packages\pandas\core\algorithms.py in factorize(values, sort, na_sentinel, size_hint, dropna)
#     646
# --> 647         codes, uniques = _factorize_array(
#     648             values, na_sentinel=na_sentinel, size_hint=size_hint, na_value=na_value
#
# D:\Users\lucas\anaconda3\envs\masters\lib\site-packages\pandas\core\algorithms.py in _factorize_array(values, na_sentinel, size_hint, na_value, mask)
#     494     table = hash_klass(size_hint or len(values))
# --> 495     uniques, codes = table.factorize(
#     496         values, na_sentinel=na_sentinel, na_value=na_value, mask=mask
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.factorize()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable._unique()
#
# TypeError: unhashable type: 'list'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-48-566996576b55> in <module>
#      15     'random choice'
#      16 )
# ---> 17 sns_confidence_interval_plot(
#      18     np.array(rnd_search_data['d2d_speffs']),
#      19     y_label,
#
# d:\dev\sys-simulator-2\sys_simulator\general\__init__.py in sns_confidence_interval_plot(y_ticks, y_label, legend)
#     298     df = pd.DataFrame({'y_tick': aux2, 'n_d2d': n_d2d})
#     299     # plot
# --> 300     sns.lineplot(x="n_d2d", y="y_tick", data=df, label=legend)
#     301     x_ticks = df['n_d2d'].unique()
#     302     x_ticks.sort()
#
# D:\Users\lucas\anaconda3\envs\masters\lib\site-packages\seaborn\relational.py in lineplot(x, y, hue, size, style, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, units, estimator, ci, n_boot, seed, sort, err_style, err_kws, legend, ax, **kwargs)
#    1130         ax = plt.gca()
#    1131
# -> 1132     p.plot(ax, kwargs)
#    1133     return ax
#    1134
#
# D:\Users\lucas\anaconda3\envs\masters\lib\site-packages\seaborn\relational.py in plot(self, ax, kws)
#     798         # Loop over the semantic subsets and draw a line for each
#     799
# --> 800         for semantics, data in self.subset_data():
#     801
#     802             hue, size, style = semantics
#
# D:\Users\lucas\anaconda3\envs\masters\lib\site-packages\seaborn\relational.py in subset_data(self)
#     329
#     330             if self.sort:
# --> 331                 subset_data = subset_data.sort_values(["units", "x", "y"])
#     332
#     333             if self.units is None:
#
# D:\Users\lucas\anaconda3\envs\masters\lib\site-packages\pandas\core\frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    5277                 keys = [Series(k, name=name) for (k, name) in zip(keys, by)]
#    5278
# -> 5279             indexer = lexsort_indexer(
#    5280                 keys, orders=ascending, na_position=na_position, key=key
#    5281             )
#
# D:\Users\lucas\anaconda3\envs\masters\lib\site-packages\pandas\core\sorting.py in lexsort_indexer(keys, orders, na_position, key)
#     234         # create the Categorical
#     235         else:
# --> 236             cat = Categorical(k, ordered=True)
#     237
#     238         if na_position not in ["last", "first"]:
#
# D:\Users\lucas\anaconda3\envs\masters\lib\site-packages\pandas\core\arrays\categorical.py in __init__(self, values, categories, ordered, dtype, fastpath)
#     343                 codes, categories = factorize(values, sort=True)
#     344             except TypeError as err:
# --> 345                 codes, categories = factorize(values, sort=False)
#     346                 if dtype.ordered:
#     347                     # raise, as we don't have a sortable data structure and so
#
# D:\Users\lucas\anaconda3\envs\masters\lib\site-packages\pandas\core\algorithms.py in factorize(values, sort, na_sentinel, size_hint, dropna)
#     645             na_value = None
#     646
# --> 647         codes, uniques = _factorize_array(
#     648             values, na_sentinel=na_sentinel, size_hint=size_hint, na_value=na_value
#     649         )
#
# D:\Users\lucas\anaconda3\envs\masters\lib\site-packages\pandas\core\algorithms.py in _factorize_array(values, na_sentinel, size_hint, na_value, mask)
#     493
#     494     table = hash_klass(size_hint or len(values))
# --> 495     uniques, codes = table.factorize(
#     496         values, na_sentinel=na_sentinel, na_value=na_value, mask=mask
#     497     )
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.factorize()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable._unique()
#
# TypeError: unhashable type: 'list'

# %%
# MUE spectral efficiencies

# %%
y_label = 'Spectral efficiency [bps/Hz]'
sns_confidence_interval_plot(
    np.array(clde_data['mue_speffs']),
    y_label,
    'CLDE'
)
sns_confidence_interval_plot(
    np.array(discent_data['mue_speffs']),
    y_label,
    'DLDE'
)
sns_confidence_interval_plot(
    np.array(random_data['mue_speffs']),
    y_label,
    'random choice'
)
sns_confidence_interval_plot(
    np.array(rnd_search_data['mue_speffs']),
    y_label,
    'random search'
)
# Out:
# <ipython-input-50-4bb92f4fc23d>:18: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   np.array(rnd_search_data['mue_speffs']),
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# D:\Users\lucas\anaconda3\envs\masters\lib\site-packages\pandas\core\arrays\categorical.py in __init__(self, values, categories, ordered, dtype, fastpath)
#     342             try:
# --> 343                 codes, categories = factorize(values, sort=True)
#     344             except TypeError as err:
#
# D:\Users\lucas\anaconda3\envs\masters\lib\site-packages\pandas\core\algorithms.py in factorize(values, sort, na_sentinel, size_hint, dropna)
#     646
# --> 647         codes, uniques = _factorize_array(
#     648             values, na_sentinel=na_sentinel, size_hint=size_hint, na_value=na_value
#
# D:\Users\lucas\anaconda3\envs\masters\lib\site-packages\pandas\core\algorithms.py in _factorize_array(values, na_sentinel, size_hint, na_value, mask)
#     494     table = hash_klass(size_hint or len(values))
# --> 495     uniques, codes = table.factorize(
#     496         values, na_sentinel=na_sentinel, na_value=na_value, mask=mask
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.factorize()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable._unique()
#
# TypeError: unhashable type: 'list'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-50-4bb92f4fc23d> in <module>
#      15     'random choice'
#      16 )
# ---> 17 sns_confidence_interval_plot(
#      18     np.array(rnd_search_data['mue_speffs']),
#      19     y_label,
#
# d:\dev\sys-simulator-2\sys_simulator\general\__init__.py in sns_confidence_interval_plot(y_ticks, y_label, legend)
#     298     df = pd.DataFrame({'y_tick': aux2, 'n_d2d': n_d2d})
#     299     # plot
# --> 300     sns.lineplot(x="n_d2d", y="y_tick", data=df, label=legend)
#     301     x_ticks = df['n_d2d'].unique()
#     302     x_ticks.sort()
#
# D:\Users\lucas\anaconda3\envs\masters\lib\site-packages\seaborn\relational.py in lineplot(x, y, hue, size, style, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, units, estimator, ci, n_boot, seed, sort, err_style, err_kws, legend, ax, **kwargs)
#    1130         ax = plt.gca()
#    1131
# -> 1132     p.plot(ax, kwargs)
#    1133     return ax
#    1134
#
# D:\Users\lucas\anaconda3\envs\masters\lib\site-packages\seaborn\relational.py in plot(self, ax, kws)
#     798         # Loop over the semantic subsets and draw a line for each
#     799
# --> 800         for semantics, data in self.subset_data():
#     801
#     802             hue, size, style = semantics
#
# D:\Users\lucas\anaconda3\envs\masters\lib\site-packages\seaborn\relational.py in subset_data(self)
#     329
#     330             if self.sort:
# --> 331                 subset_data = subset_data.sort_values(["units", "x", "y"])
#     332
#     333             if self.units is None:
#
# D:\Users\lucas\anaconda3\envs\masters\lib\site-packages\pandas\core\frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    5277                 keys = [Series(k, name=name) for (k, name) in zip(keys, by)]
#    5278
# -> 5279             indexer = lexsort_indexer(
#    5280                 keys, orders=ascending, na_position=na_position, key=key
#    5281             )
#
# D:\Users\lucas\anaconda3\envs\masters\lib\site-packages\pandas\core\sorting.py in lexsort_indexer(keys, orders, na_position, key)
#     234         # create the Categorical
#     235         else:
# --> 236             cat = Categorical(k, ordered=True)
#     237
#     238         if na_position not in ["last", "first"]:
#
# D:\Users\lucas\anaconda3\envs\masters\lib\site-packages\pandas\core\arrays\categorical.py in __init__(self, values, categories, ordered, dtype, fastpath)
#     343                 codes, categories = factorize(values, sort=True)
#     344             except TypeError as err:
# --> 345                 codes, categories = factorize(values, sort=False)
#     346                 if dtype.ordered:
#     347                     # raise, as we don't have a sortable data structure and so
#
# D:\Users\lucas\anaconda3\envs\masters\lib\site-packages\pandas\core\algorithms.py in factorize(values, sort, na_sentinel, size_hint, dropna)
#     645             na_value = None
#     646
# --> 647         codes, uniques = _factorize_array(
#     648             values, na_sentinel=na_sentinel, size_hint=size_hint, na_value=na_value
#     649         )
#
# D:\Users\lucas\anaconda3\envs\masters\lib\site-packages\pandas\core\algorithms.py in _factorize_array(values, na_sentinel, size_hint, na_value, mask)
#     493
#     494     table = hash_klass(size_hint or len(values))
# --> 495     uniques, codes = table.factorize(
#     496         values, na_sentinel=na_sentinel, na_value=na_value, mask=mask
#     497     )
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.factorize()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable._unique()
#
# TypeError: unhashable type: 'list'
